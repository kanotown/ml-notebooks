# %% [markdown]
# # 第1章 イントロダクション
#
# 『Python機械学習スタートブック』のコードをGoogle Colabで実行するためのノートブックです。
# コードは書籍のリスト番号順に並んでいます。上から順に実行してください。
#
# - 解説（Web教材）: https://ml.kano.ac/chapters/1/

# %% [markdown]
# ## 環境構築の準備

# %% [markdown]
# ### Google Colab

# %% [markdown]
# #### Google Colabの始め方

# %% [markdown]
# **リスト 1.1**　はじめてのコード実行

# %%
print("こんにちは、機械学習！")

# %% [markdown]
# **リスト 1.2**　簡単な計算の実行

# %%
# 足し算
print(1 + 2)

# 掛け算
print(3 * 4)

# べき乗（2の10乗）
print(2 ** 10)
